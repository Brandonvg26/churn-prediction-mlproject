# %% [markdown]
# Open a notebook in Databricks and run the following to create your project namespace:

# %%
# %sql

#Create a dedicated schema for your ML project
CREATE SCHEMA IF NOT EXISTS ml1.ml_project;


#Create a volume for raw data files (replaces legacy DBFS)
CREATE VOLUME IF NOT EXISTS ml1.ml_project.raw_data;


#Create a volume for model artifacts and exports
CREATE VOLUME IF NOT EXISTS ml1.ml_project.artifacts;
